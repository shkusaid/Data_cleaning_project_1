# %%
import pandas as pd

# %%
df = pd.read_csv("Airbnb_Open_Data.csv")
data = df
df.head()
# Out:
# C:\Users\shkus\AppData\Local\Temp\ipykernel_12504\1255255914.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Airbnb_Open_Data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
df.columns
# df.info()
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', #'license' 
        'id']

df_to_keep =['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']

len(df_to_drop)
# Out:
# 6

# %%
len(df_to_keep)
# Out:
# 19

# %% [markdown]
# # 1st Method Filtering Data

# %%
df1 = df[df_to_keep]
print(df1)
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# # 2nd Method Droping Columns

# %%
data.drop(columns=df_to_drop , inplace=True)
data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# # Renaming Columns

# %%
df.rename(columns={"NAME": "Name"} , inplace=True)
df
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
new_columns_names = []
for i in df:
    new_columns_names.append(i.upper())

# %%
new_columns_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW',
#  'LICENSE']

# %%
new_df_to_modify = df.copy()
new_df_to_modify.columns = new_columns_names
new_df_to_modify
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Droping NAN numbers

# %%
df.isna().sum()
# Out:
# Name                         250
# host id                        0
# host_identity_verified       289
# host name                    404
# neighbourhood group           29
# neighbourhood                 16
# lat                            8
# long                           8
# country                      532
# country code                 131
# instant_bookable             105
# cancellation_policy           76
# room type                      0
# Construction year            214
# price                        247
# service fee                  273
# minimum nights               400
# number of reviews            183
# last review                15832
# license                   102056
# dtype: int64

# %%
df.drop(columns=["last review"] , inplace=True)

# %%
df.isna().sum()
# Out:
# Name                         250
# host id                        0
# host_identity_verified       289
# host name                    404
# neighbourhood group           29
# neighbourhood                 16
# lat                            8
# long                           8
# country                      532
# country code                 131
# instant_bookable             105
# cancellation_policy           76
# room type                      0
# Construction year            214
# price                        247
# service fee                  273
# minimum nights               400
# number of reviews            183
# license                   102056
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# license                   0
# dtype: int64

# %% [markdown]
# ## Targeting/Modifying Single Column

# %%
df["host_identity_verified"] = df["host_identity_verified"].str.upper()
df
# Out:
#                                      Name      host id host_identity_verified  \
# 11114  Cozy 1 BR on Bedford Avenue, Wburg  73023181304               VERIFIED
# 72947  Cozy 1 BR on Bedford Avenue, Wburg  25804773951            UNCONFIRMED
#
#        host name neighbourhood group neighbourhood       lat      long  \
# 11114  Christina            Brooklyn  Williamsburg  40.71764 -73.95689
# 72947  Christina            Brooklyn  Williamsburg  40.71764 -73.95689
#
#              country country code instant_bookable cancellation_policy  \
# 11114  United States           US             True              strict
# 72947  United States           US             True            flexible
#
#           room type  Construction year  price service fee  minimum nights  \
# 11114  Private room             2010.0  $702        $140              1.0
# 72947  Private room             2010.0  $702        $140              1.0
#
#        number of reviews   license
# 11114                1.0  41662/AL
# ...

# %%
df["instant_bookable"].apply(lambda x : 1 if x== True else 0)
# Out:
# 11114    1
# 72947    1
# Name: instant_bookable, dtype: int64

# %%
df["instant_bookable"] = df["instant_bookable"].apply(lambda x : 1 if x== True else 0)
df.reset_index(inplace=True)

# %%
type(df["instant_bookable"][15])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\shkus\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 15 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 type(df["instant_bookable"][15])
#
# File c:\Users\shkus\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
# ...

# %% [markdown]
# ### Updating DataType

# %%
df["price"].head(3)
# Out:
# 0    $966
# 1    $142
# 2    $204
# Name: price, dtype: object

# %%
df["price"]=df["price"].str.replace("$" , "")

# %%
df["price"] = df["price"].str.replace("," , "")

# %%
df["price"]= df["price"].str.replace(" " , "")

# %%
type(df["price"])
# Out:
# pandas.core.series.Series

# %%
df["price"] = df["price"].astype(int)

# %%
df["price"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: int64

# %%
df
# Out:
#        level_0   index                                              Name  \
# 0            0       0                Clean & quiet apt home by the park
# 1            1       1                             Skylit Midtown Castle
# 2            2       4  Entire Apt: Spacious Studio/Loft by central park
# 3            3       5         Large Cozy 1 BR Apartment In Midtown East
# 4            4       7                                   BlissArtsSpace!
# ...        ...     ...                                               ...
# 99337    99337  102029            Cozy room in a 2B with backyard access
# 99338    99338  102030                      An East Williamsburg Delight
# 99339    99339  102031                      Cozy bedroom in williamsburg
# 99340    99340  102032                            Spacious Room w/ 2 Bed
# 99341    99341  102040                     Room in Queens, NY, near LGA.
#
#            host id host_identity_verified  host name neighbourhood group  \
# ...

# %%
df["service fee"] = df["service fee"].str.replace("$" , "")
df["service fee"] = df["service fee"].str.replace("," , "")
df["service fee"] = df["service fee"].str.replace(" " , "")
# replacements = {
#     "$" : "",
#     "," : "",
#     " " : ""
# }

# for old , new in replacements.items():
#     df["service fee"] = df["service fee"].str.replace(old , new) #............ this wont work cz column has diff DT
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df["service fee"] = df["service fee"].str.replace("$" , "")
#       2 df["service fee"] = df["service fee"].str.replace("," , "")
#       3 df["service fee"] = df["service fee"].str.replace(" " , "")
#
# File c:\Users\shkus\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Users\shkus\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df["service fee"] = df["service fee"].astype(int)

# %%
df["service fee"]
# Out:
# 0        193
# 1         28
# 2         41
# 3        115
# 4        212
#         ...
# 99337    164
# 99338     91
# 99339    216
# 99340     21
# 99341    196
# Name: service fee, Length: 99342, dtype: int64

# %%
df
# Out:
#        level_0   index                                              Name  \
# 0            0       0                Clean & quiet apt home by the park
# 1            1       1                             Skylit Midtown Castle
# 2            2       4  Entire Apt: Spacious Studio/Loft by central park
# 3            3       5         Large Cozy 1 BR Apartment In Midtown East
# 4            4       7                                   BlissArtsSpace!
# ...        ...     ...                                               ...
# 99337    99337  102029            Cozy room in a 2B with backyard access
# 99338    99338  102030                      An East Williamsburg Delight
# 99339    99339  102031                      Cozy bedroom in williamsburg
# 99340    99340  102032                            Spacious Room w/ 2 Bed
# 99341    99341  102040                     Room in Queens, NY, near LGA.
#
#            host id host_identity_verified  host name neighbourhood group  \
# ...

# %%
df.drop(columns= ["index"] , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.drop(columns= ["index"] , inplace=True)
#
# File c:\Users\shkus\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
# ...

# %% [markdown]
# ## Saving to CSV

# %%
df.to_csv("cleaned_data.csv")

# %%
pd.read_csv("cleaned_data.csv")
# Out:
#    Unnamed: 0                                Name      host id  \
# 0           0  Cozy 1 BR on Bedford Avenue, Wburg  73023181304
# 1           1  Cozy 1 BR on Bedford Avenue, Wburg  25804773951
#
#   host_identity_verified  host name neighbourhood group neighbourhood  \
# 0               VERIFIED  Christina            Brooklyn  Williamsburg
# 1            UNCONFIRMED  Christina            Brooklyn  Williamsburg
#
#         lat      long        country country code  instant_bookable  \
# 0  40.71764 -73.95689  United States           US                 1
# 1  40.71764 -73.95689  United States           US                 1
#
#   cancellation_policy     room type  Construction year  price service fee  \
# 0              strict  Private room             2010.0  $702        $140
# 1            flexible  Private room             2010.0  $702        $140
#
#    minimum nights  number of reviews   license
# 0             1.0                1.0  41662/AL
# ...

# %%
df.to_csv("cleaned_data_without_index" , index=False)

# %%
pd.read_csv("cleaned_data_without_index").head()
# Out:
#                                  Name      host id host_identity_verified  \
# 0  Cozy 1 BR on Bedford Avenue, Wburg  73023181304               VERIFIED
# 1  Cozy 1 BR on Bedford Avenue, Wburg  25804773951            UNCONFIRMED
#
#    host name neighbourhood group neighbourhood       lat      long  \
# 0  Christina            Brooklyn  Williamsburg  40.71764 -73.95689
# 1  Christina            Brooklyn  Williamsburg  40.71764 -73.95689
#
#          country country code  instant_bookable cancellation_policy  \
# 0  United States           US                 1              strict
# 1  United States           US                 1            flexible
#
#       room type  Construction year  price service fee  minimum nights  \
# 0  Private room             2010.0  $702        $140              1.0
# 1  Private room             2010.0  $702        $140              1.0
#
#    number of reviews   license
# 0                1.0  41662/AL
# 1                1.0  41662/AL
